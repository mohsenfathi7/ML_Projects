# %% [markdown]
# # Clone git repository

# %%
! git clone https://github.com/adamian98/pulse.git
# Out:
# Cloning into 'pulse'...
# remote: Enumerating objects: 102, done.
# remote: Total 102 (delta 0), reused 0 (delta 0), pack-reused 102
# Receiving objects: 100% (102/102), 164.43 MiB | 36.47 MiB/s, done.
# Resolving deltas: 100% (45/45), done.

# %% [markdown]
# # Create needed folder

# %%
# !mkdir /content/pulse/realpics
# !mkdir /content/pulse/input

# %% [markdown]
# # Copy input images to realpics folder

# %%
# !cp '/content/drive/MyDrive/Colab Notebooks/test1.jpg' '/content/pulse/realpics'
# !cp '/content/drive/MyDrive/Colab Notebooks/test2.jpg' '/content/pulse/realpics'

# %% [markdown]
# # Prepare input image for model

# %%
# %cd /content/pulse
# !python align_face.py
# Out:
# /content/pulse
# ...
# test2.jpg: Number of faces detected: 1
# test1.jpg: Number of faces detected: 1

# %% [markdown]
# # Run model

# %%
# !python run.py
# Out:
# Loading Synthesis Network
# Optimizing
# BEST (100) | L2: 0.0020 | GEOCROSS: 2.0962 | TOTAL: 0.3048 | time: 8.6 | it/s: 11.61 | batchsize: 1
# Optimizing
# BEST (100) | L2: 0.0020 | GEOCROSS: 2.5436 | TOTAL: 0.3272 | time: 8.6 | it/s: 11.63 | batchsize: 1
